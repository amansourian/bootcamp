# %%
import numpy as np
import pandas as pd

import skimage
import skimage.io

# Use IPython widgets for interacting
import ipywidgets

# Import Bokeh modules for interactive plotting
import bkcharts
import bokeh.io
import bokeh.models
import bokeh.palettes
import bokeh.plotting

# I like the default Matplotlib palette
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']

# Display graphics in this notebook
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c9258f61-e26d-4faa-b0c3-da1590e1dd14">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv('data/grant_complete.csv')
df_1987 = df.loc[df['year']==1987, :]

# %%
tooltips = [('band', '@band')]
p = bkcharts.Scatter(df_1987, x='beak length (mm)', y='beak depth (mm)', color='species',
                     palette=colors, width=600, height=400, tooltips=tooltips)
bokeh.io.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a56e68eb-2fa6-4682-90ea-9e4119277885"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a56e68eb-2fa6-4682-90ea-9e4119277885");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a56e68eb-2fa6-4682-90ea-9e4119277885");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a56e68eb-2fa6-4682-90ea-9e4119277885' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"da7bd7d4-314f-418b-bcc0-f1a38d2d1329":{"roots":{"references":[{"attributes":{"callback":null,"plot":{"id":"c8035d56-36f1-446f-bbf4-51da52b6859f","subtype":"Chart","type":"Plot"},"tooltips":[["band","@band"]]},"id":"2fe2c247-5bdf-43e3-89e6-e289db6a31db","type":"HoverTool"},{"attributes":{"dimension":1,"plot":{"id":"c8035d56-36f1-446f-bbf4-51da52b6859f","subtype":"Chart","type":"Plot"},"ticker":{"id":"0cd58669-c889-465c-86bc-64920d321999","type":"BasicTicker"}},"id":"e093cd5a-2c7a-414f-aa98-5789fe4537bf","type":"Grid"},{"attributes":{},"id":"21efc0fb-414a-4166-a08a-24a7b279295c","type":"ToolEvents"},{"attributes":{},"id":"580fdc31-831f-40f8-942a-8963831a198c","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"c8035d56-36f1-446f-bbf4-51da52b6859f","subtype":"Chart","type":"Plot"}},"id":"9f1c064a-9e87-4a77-b9d0-966f9d93bdbf","type":"SaveTool"},{"attributes":{"plot":{"id":"c8035d56-36f1-446f-bbf4-51da52b6859f","subtype":"Chart","type":"Plot"}},"id":"1ae58717-2d2a-4b4a-bb8f-c7698cfd0f21","type":"WheelZoomTool"},{"attributes":{"axis_label":"beak length (mm)","formatter":{"id":"580fdc31-831f-40f8-942a-8963831a198c","type":"BasicTickFormatter"},"plot":{"id":"c8035d56-36f1-446f-bbf4-51da52b6859f","subtype":"Chart","type":"Plot"},"ticker":{"id":"26c19417-8e20-4c4a-85a2-c175426a80b9","type":"BasicTicker"}},"id":"33e3a004-4efb-411d-9b34-a2dac442012e","type":"LinearAxis"},{"attributes":{"plot":{"id":"c8035d56-36f1-446f-bbf4-51da52b6859f","subtype":"Chart","type":"Plot"},"ticker":{"id":"26c19417-8e20-4c4a-85a2-c175426a80b9","type":"BasicTicker"}},"id":"eb25a263-6309-4d29-b8d4-9aa5500b5c1a","type":"Grid"},{"attributes":{},"id":"26c19417-8e20-4c4a-85a2-c175426a80b9","type":"BasicTicker"},{"attributes":{"callback":null,"end":13.27,"start":6.43},"id":"603bbe54-5509-431e-a045-0903f262952b","type":"Range1d"},{"attributes":{"label":{"value":"scandens"},"renderers":[{"id":"a470b046-2bf5-44d1-9300-d700c8c1d5ce","type":"GlyphRenderer"}]},"id":"6bf4491e-310e-4925-9636-38ec1ef89d98","type":"LegendItem"},{"attributes":{"plot":{"id":"c8035d56-36f1-446f-bbf4-51da52b6859f","subtype":"Chart","type":"Plot"}},"id":"6767dad6-c8dc-4e22-8537-6364b768dce8","type":"ResetTool"},{"attributes":{"below":[{"id":"33e3a004-4efb-411d-9b34-a2dac442012e","type":"LinearAxis"}],"css_classes":null,"height":400,"left":[{"id":"05659f0e-bf99-4989-ae74-d395bc972a9b","type":"LinearAxis"}],"renderers":[{"id":"5b970963-7867-4138-8d25-4c6f78c2ec22","type":"BoxAnnotation"},{"id":"0ac5f3cc-f798-450d-b248-5dbc7b453353","type":"GlyphRenderer"},{"id":"a470b046-2bf5-44d1-9300-d700c8c1d5ce","type":"GlyphRenderer"},{"id":"d46d8d19-fb00-4db9-add1-2cb5d0edcc6a","type":"Legend"},{"id":"33e3a004-4efb-411d-9b34-a2dac442012e","type":"LinearAxis"},{"id":"05659f0e-bf99-4989-ae74-d395bc972a9b","type":"LinearAxis"},{"id":"eb25a263-6309-4d29-b8d4-9aa5500b5c
","type":"Circle"},{"attributes":{"callback":null,"column_names":["x0s","y0s","x1s","y1s"],"data":{"chart_index":[{"species":"fortis"},{"species":"fortis"},{"species":"fortis"},{"species":"fortis"}],"species":["fortis","fortis","fortis","fortis"],"x0s":["fortis:0.5","fortis:0.65","fortis:0.5","fortis:0.65"],"x1s":["fortis:0.5","fortis:0.35","fortis:0.5","fortis:0.35"],"y0s":[8.840000000000002,8.840000000000002,11.44,12.999999999999998],"y1s":[10.4,8.840000000000002,12.999999999999998,12.999999999999998]}},"id":"0be0971a-6d08-4db6-86a3-cbcdb068e15d","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"8188bf44-9ca7-49cd-8a05-372085ad4cf3","subtype":"Chart","type":"Plot"}},"id":"b5243454-e2d4-444d-a5ec-109a969b47b8","type":"ResetTool"},{"attributes":{"plot":{"id":"8188bf44-9ca7-49cd-8a05-372085ad4cf3","subtype":"Chart","type":"Plot"}},"id":"313ae4c8-5818-4270-b99a-cc29bc7d0522","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"species":"scandens"}],"color":["DimGrey"],"fill_alpha":[0.8],"height":[0.4175000000000004],"label":[{"species":"scandens"}],"line_alpha":[1.0],"line_color":["black"],"species":["scandens"],"width":[0.8],"x":["scandens"],"y":[14.046249999999999]}},"id":"88c3497f-b27e-491d-92b0-59e5949831e7","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll" ...

# %% [markdown]
# Lower level Bokeh

# %%
p = bokeh.plotting.figure(height=400, width=600, x_axis_label='beak length (mm)',
                          y_axis_label='beak depth (mm)')

hover = bokeh.models.HoverTool(tooltips=[('band', '@band'),
                                         ('length', '@{beak length (mm)}{0.2f}'),
                                         ('depth', '@{beak depth (mm)}{0.2f}')])

p.add_tools(hover)

# %%
df_fortis = df_1987.loc[df_1987['species']=='fortis', :]
df_scandens = df_1987.loc[df_1987['species']=='scandens', :]

# %%
p.circle('beak length (mm)', 'beak depth (mm)', source=df_fortis, color=colors[0],
         alpha=0.25, size=6)
p.circle('beak length (mm)', 'beak depth (mm)', source=df_scandens, color=colors[1],
         alpha=0.25, size=6)

bokeh.io.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="34aa2fe8-8bbd-4fef-95af-fc060a875013"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("34aa2fe8-8bbd-4fef-95af-fc060a875013");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("34aa2fe8-8bbd-4fef-95af-fc060a875013");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '34aa2fe8-8bbd-4fef-95af-fc060a875013' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"313fb7e5-5f56-4f7b-926a-32780035a883":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["band","beak depth (mm)","beak length (mm)","species","year","index"],"data":{"band":[15718,5594,15235,15252,15847,15139,15237,4045,8443,15798,14786,364,10001,15119,15676,15476,14576,15419,15635,2733,15751,14834,4109,15901,14830,15086,15986,4223,15725,13554,15407,3425,15704,15102,5582,15121,10770,14755,13555,15765,15243,8441,10067,15406,15234,15608,14758,14835,15882,14787,14727,5351,15859,15721,5663,2543,5013,10394,17548,14647,13548,5345,15760,15685,14731,14906,15330,4577,4744,10984,14759,15639,15090,4221,15422,15441,15736,4683,14768,5375,14843,2554,14995,15638,15837,10002,14584,14730,3458,5911,2760,15812,5367,10174,1645,4090,5576,14975,2877,10206,4778,5322,10207,10740,8450,10517,2758,14729,10743,13527,8444,15738,2445,5931,14728,15615,14646,13526,15343,10105,14645,2433,10268,10245,4706,14918,15694,15421,14208,1396,1444,4051,10061,4701,13257,2949,14946,5656,5608,15352,15817,4119,10223,2969,14648,15658,13256,8425,14524,10075,4137,14847,15886,14877,8036,14579],"beak depth (mm)":{"__ndarray__":"...","dtype":"float64","shape":[156]},"beak length (mm)":{"__ndarray__":"...","dtype":"float64","shape":[156]},"index":[1275,1276,1277,1278,1279,1280,1281,1282,1283,1284,1285,1286,1287,1288,1289,1290,1291,1292,1293,1294,1295,1296,1297,1298,1299,1300,1301,1302,1303,1304,1305,1306,1307,1308,1309,1310,1311,1312,1313,1314,1315,1316,1317,1318,1319,1320,1321,1322,1323,1324,1325,1326,1327,1328,1329,1330,1331,1332,1333,1334,1335,1336,1337,1338,1339,1340,1341,1342,1343,1344,1345,1346,1347,1348,1349,1350,1351,1352,1353,1354,1355,1356,1357,1358,1359,1360,1361,1362,1363,1364,1365,1366,1367,1368,1369,1370,1371,1372,1373,1374,1375,1376,1377,1378,1379,1380,1381,1382,1383,1384,1385,1386,1387,1388,1389,1390,1391,1392,1393,1394,1395,1396,1397,1398,1399,1400,1401,1402,1403,1404,1405,1406,1407,1408,1409,1410,1411,1412,1413,1414,1415,1416,1417,1418,1419,1420,1421,1422,1423,1424,1425,1426,1427,1428,1429,1430],"species":["scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens"],"year":[1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,198 ...

# %%
bokeh.io.output_file('beaks_1987.html', title='Daphne Major finch beaks 1987')
bokeh.io.save(p)
# Out:
# '/Users/arman/git/bootcamp/beaks_1987.html'
